# %% [markdown]
# Etapas avaliadas serão:
#
#     1. Webscrapping de dados de saúde (Processo utilizando alguma das bibliotecas ministradas no curso).
#     2. Projeto no GitHub (Com documentação e README).
#     3. Desenvolvimento de um pipeline, detalhando as etapas envolvidas desde o webscrapping até a entrega de uma
#     base pronta para análise (ferramentas, sistema, linguagem utilizados). Pode ser em formato de texto usando fluxo de tarefas,
#     com imagens usando um fluxograma e texto para complementar com descrição de cada tarefa.
#     4. Manipulação de dados e transformação (avaliados através de scripts de manipulação usando técnicas similares as ministradas em aula).
#     5. Agregação de dados e junção (merge) de bases de dados (também avaliado através dos scripts).
#     6. Descritiva simples de pelo menos 10 variáveis da base final (se for numérica, avaliar média,
#     mediana e fazer um boxplot, se for categórica mostrar percentuais de preenchimento em cada categoria, se for data, avaliar mínimo e máximo).
#     7. Entregar um dicionário das principais variáveis na base de dados (entre 10-15 variáveis),
#     contendo o nome da variável, uma descrição breve, o tipo, e a completude na base de dados.
#
# As problemáticas disponíveis para seleção, e, portanto, o problema no qual vocês irão trabalhar estarão dispostas abaixo.
# Além disso, na etapa de webscrapping, precisaremos de dados das bases de saúde de pelo menos 5 anos (os 5 mais atuais disponíveis),
# e para os dados socioeconômicos se possível também dos últimos 5 anos (se for um índice único, utilizar apenas o que está disponível).

# %% [markdown]
# O pesquisador quer avaliar as condições de óbitos usando alguns dados socioeconômicos, observando se existe alguma relação entre municípios com maior IVS (Índice de Vulnerabilidade Social) ou pior IED (Índice de Equidade e Dimensionamento) em relação à quantidade de óbitos.
#
# Para isso ele precisará das informações:
#
#     Sobre óbito;
#     Se o evento está relacionado ao processo de trabalho;
#     Se houve correção ou alteração da causa do óbito após investigação;
#     O(s) CID(s) informados no atestado de óbito, a causa básica da declaração do óbito (CID 10);
#     O código do município de residência, a data de nascimento e data de óbito;
#     Também tem interesse em saber o nível de escolaridade do indivíduo e escolaridade da mãe (se disponível);
#     E informações sobre raça/cor do indivíduo.
#
#     E para informações socioeconômicas queremos os valores de IED e IVS, além do número de habitantes e a faixa de porte populacional segundo o IBGE.
#     Dados:
#
# -
# SIM: https://dados.gov.br/dados/conjuntos-dados/sim-1979-2019
# -
# IED e IVS - https://www.in.gov.br/en/web/dou/-/portaria-gm/ms-n-3.493-de-10-de-abril-de-2024-553573811

# %%
from bs4 import BeautifulSoup
import pandas as pd
import ssl

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import requests
from time import sleep
from random import randint

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
indices = pd.read_html('https://www.in.gov.br/en/web/dou/-/portaria-gm/ms-n-3.493-de-10-de-abril-de-2024-553573811', header=1)[5:]

# %%
display(indices)
# Out:
# [     UF    IBGE Nome do MunicÃ­pio  Ãndice de Vulnerabilidade Social  \
#  0    AC  120001        ACRELÃNDIA                                  2
#  1    AC  120005       ASSIS BRASIL                                  2
#  2    AC  120010         BRASILÃIA                                  2
#  3    AC  120013             BUJARI                                  2
#  4    AC  120017           CAPIXABA                                  2
#  ..   ..     ...                ...                                ...
#  123  AL  270940            VIÃOSA                                  2
#  124  AM  130002          ALVARÃES                                  1
#  125  AM  130006           AMATURÃ                                  1
#  126  AM  130008             ANAMÃ                                  1
#  127  AM  130010              ANORI                                  1
#
#       NÃºmero de habitantes segundo o IBGE 2022  \
#  0                                       14.021
#  1                                        8.100
#  2                                       26.000
#  3                                       12.917
#  4                                       10.392
#  ..                                         ...
#  123                                     23.972
#  124                                     15.866
#  125                                     10.819
#  126                                      9.962
#  127                                     17.194
#
#      Faixa de Porte Populacional segundo o IBGE 2022  \
#  0                                 1-AtÃ© 20mil hab.
#  1                                 1-AtÃ© 20mil hab.
#  2                  2-Acima de 20mil atÃ© 50mil hab.
#  3                                 1-AtÃ© 20mil hab.
#  4                                 1-AtÃ© 20mil hab.
#  ..                                              ...
#  123                2-Acima de 20mil atÃ© 50mil hab.
#  124                               1-AtÃ© 20mil hab.
#  125                               1-AtÃ© 20mil hab.
#  126                               1-AtÃ© 20mil hab.
#  127                               1-AtÃ© 20mil hab.
#
#       Ãndice de Equidade e Dimensionamento (IED)
#  0                                              2
#  1                                              2
#  2                                              2
#  3                                              2
#  4                                              2
#  ..                                           ...
#  123                                            2
#  124                                            1
#  125                                            1
#  126                                            1
#  127                                            1
#
#  [128 rows x 7 columns],
#       AM  130014              APUÃ  2  20.647  \
#  0    AM  130020   ATALAIA DO NORTE  1  15.314
#  1    AM  130030            AUTAZES  1  41.564
#  2    AM  130040           BARCELOS  1  18.834
#  3    AM  130050        BARREIRINHA  1  31.051
#  4    AM  130060  BENJAMIN CONSTANT  1  37.648
#  ..   ..     ...                ... ..     ...
#  112  BA  290323         BARRO ALTO  2  13.453
#  113  BA  290327           BARROCAS  2  15.203
#  114  BA  290330        BARRO PRETO  1   5.833
#  115  BA  290340           BELMONTE  1  20.121
#  116  BA  290350         BELO CAMPO  2  18.412
#
#       2-Acima de 20mil atÃ© 50mil hab.  2.1
#  0                   1-AtÃ© 20mil hab.    1
#  1    2-Acima de 20mil atÃ© 50mil hab.    1
#  2                   1-AtÃ© 20mil hab.    1
#  3    2-Acima de 20mil atÃ© 50mil hab.    1
#  4    2-Acima de 20mil atÃ© 50mil hab.    1
#  ..                                ...  ...
#  112                 1-AtÃ© 20mil hab.    2
#  113                 1-AtÃ© 20mil hab.    2
#  114                 1-AtÃ© 20mil hab.    1
#  115  2-Acima de 20mil atÃ© 50mil hab.    1
#  116                 1-AtÃ© 20mil hab.    2
#
#  [117 rows x 7 columns],
#       BA  290360           BIRITINGA  1  15.146  \
#  0    BA  290370            BOA NOVA  1  13.690
#  1    BA  290380  BOA VISTA DO TUPIM  1  16.873
#  2    BA  290390   BOM JESUS DA LAPA  2  65.550
#  3    BA  290395  BOM JESUS DA SERRA  1   9.730
#  4    BA  290400             BONINAL  2  13.622
#  ..   ..     ...                 ... ..     ...
#  140  BA  291560           ITAMARAJU  2  59.605
#  141  BA  291570             ITAMARI  2   7.051
#  142  BA  291580             ITAMBÃ  2  24.394
#  143  BA  291590            ITANAGRA  1   5.914
#  144  BA  291600            ITANHÃM  3  17.813
#
#                       1-AtÃ© 20mil hab.  1.1
#  0                    1-AtÃ© 20mil hab.    1
#  1                    1-AtÃ© 20mil hab.    1
#  2    3-Acima de 50mil atÃ© 100mil hab.    3
#  3                    1-AtÃ© 20mil hab.    1
#  4                    1-AtÃ© 20mil hab.    2
#  ..                                 ...  ...
#  140  3-Acima de 50mil atÃ© 100mil hab.    3
#  141                  1-AtÃ© 20mil hab.    2
#  142   2-Acima de 20mil atÃ© 50mil hab.    2
#  143                  1-AtÃ© 20mil hab.    1
#  144                  1-AtÃ© 20mil hab.    3
#
#  [145 rows x 7 columns],
#       BA  291610        ITAPARICA  2  19.789  \
#  0    BA  291620           ITAPÃ  2  10.341
#  1    BA  291630          ITAPEBI  2   9.174
#  2    BA  291640       ITAPETINGA  4  65.897
#  3    BA  291650        ITAPICURU  1  31.679
#  4    BA  291660       ITAPITANGA  2  10.279
#  ..   ..     ...              ... ..     ...
#  108  BA  292450          PINDAÃ  2  14.731
#  109  BA  292460       PINDOBAÃU  2  19.083
#  110  BA  292465         PINTADAS  2  10.325
#  111  BA  292467  PIRAÃ DO NORTE  1  10.974
#  112  BA  292470          PIRIPÃ  2   9.171
#
#                       1-AtÃ© 20mil hab.  2.1
#  0                    1-AtÃ© 20mil hab.    2
#  1                    1-AtÃ© 20mil hab.    2
#  2    3-Acima de 50mil atÃ© 100mil hab.    4
#  3     2-Acima de 20mil atÃ© 50mil hab.    1
#  4                    1-AtÃ© 20mil hab.    2
#  ..                                 ...  ...
#  108                  1-AtÃ© 20mil hab.    2
#  109                  1-AtÃ© 20mil hab.    2
#  110                  1-AtÃ© 20mil hab.    2
#  111                  1-AtÃ© 20mil hab.    1
#  112                  1-AtÃ© 20mil hab.    2
#
#  [113 rows x 7 columns],
#       BA  292480               PIRITIBA  1   17.566  \
#  0    BA  292490             PLANALTINO  1    8.022
#  1    BA  292500               PLANALTO  2   23.334
#  2    BA  292510               POÃÃES  2   48.293
#  3    BA  292520                 POJUCA  3   32.136
#  4    BA  292525             PONTO NOVO  2   17.938
#  ..   ..     ...                    ... ..      ...
#  107  BA  293330  VITÃRIA DA CONQUISTA  3  370.879
#  108  BA  293340                 WAGNER  2    9.503
#  109  BA  293345              WANDERLEY  2   12.968
#  110  BA  293350   WENCESLAU GUIMARÃES  1   24.474
#  111  BA  293360            XIQUE-XIQUE  2   44.757
#
#                      1-AtÃ© 20mil hab.  1.1
#  0                   1-AtÃ© 20mil hab.    1
#  1    2-Acima de 20mil atÃ© 50mil hab.    2
#  2    2-Acima de 20mil atÃ© 50mil hab.    2
#  3    2-Acima de 20mil atÃ© 50mil hab.    3
#  4                   1-AtÃ© 20mil hab.    2
#  ..                                ...  ...
#  107            4-Acima de 100mil hab.    4
#  108                 1-AtÃ© 20mil hab.    2
#  109                 1-AtÃ© 20mil hab.    2
#  110  2-Acima de 20mil atÃ© 50mil hab.    1
#  111  2-Acima de 20mil atÃ© 50mil hab.    2
#
#  [112 rows x 7 columns],
#       CE  230010          ABAIARA  2  10.038  \
#  0    CE  230015          ACARAPE  2  14.027
#  1    CE  230020          ACARAÃ  1  65.264
#  2    CE  230030         ACOPIARA  2  44.962
#  3    CE  230040           AIUABA  2  14.076
#  4    CE  230050      ALCÃNTARAS  2  11.369
#  ..   ..     ...              ... ..     ...
#  503  GO  522190          VARJÃO  4   3.716
#  504  GO  522200      VIANÃPOLIS  4  14.956
#  505  GO  522205  VICENTINÃPOLIS  2   8.768
#  506  GO  522220         VILA BOA  3   4.215
#  507  GO  522230   VILA PROPÃCIO  4   5.815
#
#                       1-AtÃ© 20mil hab.  2.1
#  0                    1-AtÃ© 20mil hab.    2
#  1    3-Acima de 50mil atÃ© 100mil hab.    2
#  2     2-Acima de 20mil atÃ© 50mil hab.    2
#  3                    1-AtÃ© 20mil hab.    2
#  4                    1-AtÃ© 20mil hab.    2
#  ..                                 ...  ...
#  503                  1-AtÃ© 20mil hab.    3
#  504                  1-AtÃ© 20mil hab.    3
#  505                  1-AtÃ© 20mil hab.    2
#  506                  1-AtÃ© 20mil hab.    3
#  507                  1-AtÃ© 20mil hab.    3
#
#  [508 rows x 7 columns],
#       MA  210005              AÃAILÃNDIA  3 106.550  \
#  0    MA  210010              AFONSO CUNHA  1   6.144
#  1    MA  210015   ÃGUA DOCE DO MARANHÃO  1  12.142
#  2    MA  210020                ALCÃNTARA  1  18.467
#  3    MA  210030             ALDEIAS ALTAS  1  23.286
#  4    MA  210040     ALTAMIRA DO MARANHÃO  1   6.447
#  ..   ..     ...                       ... ..     ...
#  211  MA  211280                     VIANA  1  51.442
#  212  MA  211285  VILA NOVA DOS MARTÃRIOS  1  10.362
#  213  MA  211290        VITÃRIA DO MEARIM  1  30.805
#  214  MA  211300           VITORINO FREIRE  1  30.845
#  215  MA  211400                  ZÃ DOCA  1  40.801
#
#                  4-Acima de 100mil hab.  4
#  0                    1-AtÃ© 20mil hab.  1
#  1                    1-AtÃ© 20mil hab.  1
#  2                    1-AtÃ© 20mil hab.  1
#  3     2-Acima de 20mil atÃ© 50mil hab.  1
#  4                    1-AtÃ© 20mil hab.  1
#  ..                                 ... ..
#  211  3-Acima de 50mil atÃ© 100mil hab.  2
#  212                  1-AtÃ© 20mil hab.  1
#  213   2-Acima de 20mil atÃ© 50mil hab.  1
#  214   2-Acima de 20mil atÃ© 50mil hab.  1
#  215   2-Acima de 20mil atÃ© 50mil hab.  1
#
#  [216 rows x 7 columns],
#       MG  310010 ABADIA DOS DOURADOS  4   6.272  \
#  0    MG  310020             ABAETÃ  4  22.675
#  1    MG  310030          ABRE CAMPO  4  13.927
#  2    MG  310040             ACAIACA  3   3.909
#  3    MG  310050            AÃUCENA  1   8.943
#  4    MG  310060           ÃGUA BOA  2  12.589
#  ..   ..     ...                 ... ..     ...
#  460  MG  314010             MARILAC  3   4.224
#  461  MG  314015       MÃRIO CAMPOS  3  15.900
#  462  MG  314020    MARIPÃ DE MINAS  4   3.387
#  463  MG  314030          MARLIÃRIA  4   4.592
#  464  MG  314040       MARMELÃPOLIS  3   3.200
#
#                      1-AtÃ© 20mil hab.  3
#  0    2-Acima de 20mil atÃ© 50mil hab.  4
#  1                   1-AtÃ© 20mil hab.  3
#  2                   1-AtÃ© 20mil hab.  3
#  3                   1-AtÃ© 20mil hab.  1
#  4                   1-AtÃ© 20mil hab.  2
#  ..                                ... ..
#  460                 1-AtÃ© 20mil hab.  3
#  461                 1-AtÃ© 20mil hab.  3
#  462                 1-AtÃ© 20mil hab.  3
#  463                 1-AtÃ© 20mil hab.  3
#  464                 1-AtÃ© 20mil hab.  3
#
#  [465 rows x 7 columns],
#       MG  314050         MARTINHO CAMPOS  4  14.003  \
#  0    MG  314053          MARTINS SOARES  4   8.396
#  1    MG  314055              MATA VERDE  2   9.112
#  2    MG  314060            MATERLÃNDIA  1   3.963
#  3    MG  314070             MATEUS LEME  3  37.841
#  4    MG  314080          MATIAS BARBOSA  4  14.121
#  ..   ..     ...                     ... ..     ...
#  381  MG  317180           VIRGINÃPOLIS  3  10.314
#  382  MG  317190            VIRGOLÃNDIA  2   4.552
#  383  MG  317200  VISCONDE DO RIO BRANCO  4  39.160
#  384  MG  317210            VOLTA GRANDE  4   4.443
#  385  MG  317220          WENCESLAU BRAZ  3   2.356
#
#                      1-AtÃ© 20mil hab.  3
#  0                   1-AtÃ© 20mil hab.  3
#  1                   1-AtÃ© 20mil hab.  2
#  2                   1-AtÃ© 20mil hab.  1
#  3    2-Acima de 20mil atÃ© 50mil hab.  3
#  4                   1-AtÃ© 20mil hab.  3
#  ..                                ... ..
#  381                 1-AtÃ© 20mil hab.  3
#  382                 1-AtÃ© 20mil hab.  2
#  383  2-Acima de 20mil atÃ© 50mil hab.  4
#  384                 1-AtÃ© 20mil hab.  3
#  385                 1-AtÃ© 20mil hab.  3
#
#  [386 rows x 7 columns],
#       MS  500020        ÃGUA CLARA  3  16.741  \
#  0    MS  500025       ALCINÃPOLIS  4   4.537
#  1    MS  500060            AMAMBAI  3  39.325
#  2    MS  500070         ANASTÃCIO  3  24.114
#  3    MS  500080      ANAURILÃNDIA  4   7.653
#  4    MS  500085          ANGÃLICA  3  10.729
#  ..   ..     ...                ... ..     ...
#  358  PA  150815            URUARÃ  1  43.558
#  359  PA  150820              VIGIA  2  50.832
#  360  PA  150830              VISEU  1  58.692
#  361  PA  150835  VITÃRIA DO XINGU  1  15.607
#  362  PA  150840           XINGUARA  3  52.893
#
#                       1-AtÃ© 20mil hab.  3.1
#  0                    1-AtÃ© 20mil hab.    3
#  1     2-Acima de 20mil atÃ© 50mil hab.    3
#  2     2-Acima de 20mil atÃ© 50mil hab.    3
#  3                    1-AtÃ© 20mil hab.    3
#  4                    1-AtÃ© 20mil hab.    3
#  ..                                 ...  ...
#  358   2-Acima de 20mil atÃ© 50mil hab.    1
#  359  3-Acima de 50mil atÃ© 100mil hab.    3
#  360  3-Acima de 50mil atÃ© 100mil hab.    2
#  361                  1-AtÃ© 20mil hab.    1
#  362  3-Acima de 50mil atÃ© 100mil hab.    3
#
#  [363 rows x 7 columns],
#       PB  250010              ÃGUA BRANCA  2    9.335  \
#  0    PB  250020                    AGUIAR  3    5.003
#  1    PB  250030             ALAGOA GRANDE  1   26.062
#  2    PB  250040               ALAGOA NOVA  2   21.013
#  3    PB  250050                 ALAGOINHA  2   13.725
#  4    PB  250053                  ALCANTIL  1    5.578
#  ..   ..     ...                       ... ..      ...
#  402  PE  261618        VERTENTE DO LÃRIO  2    7.558
#  403  PE  261620                 VERTENTES  2   21.959
#  404  PE  261630                 VICÃNCIA  2   26.355
#  405  PE  261640  VITÃRIA DE SANTO ANTÃO  2  134.084
#  406  PE  261650                    XEXÃU  1   11.611
#
#                      1-AtÃ© 20mil hab.  2.1
#  0                   1-AtÃ© 20mil hab.    3
#  1    2-Acima de 20mil atÃ© 50mil hab.    1
#  2    2-Acima de 20mil atÃ© 50mil hab.    2
#  3                   1-AtÃ© 20mil hab.    2
#  4                   1-AtÃ© 20mil hab.    1
#  ..                                ...  ...
#  402                 1-AtÃ© 20mil hab.    2
#  403  2-Acima de 20mil atÃ© 50mil hab.    2
#  404  2-Acima de 20mil atÃ© 50mil hab.    2
#  405            4-Acima de 100mil hab.    3
#  406                 1-AtÃ© 20mil hab.    1
#
#  [407 rows x 7 columns],
#       PI  220005               ACAUÃ  2    6.420       1-AtÃ© 20mil hab.  2.1
#  0    PI  220010        AGRICOLÃNDIA  1    4.940       1-AtÃ© 20mil hab.    1
#  1    PI  220020         ÃGUA BRANCA  3   17.573       1-AtÃ© 20mil hab.    3
#  2    PI  220025  ALAGOINHA DO PIAUÃ  2    6.819       1-AtÃ© 20mil hab.    2
#  3    PI  220027   ALEGRETE DO PIAUÃ  2    4.634       1-AtÃ© 20mil hab.    2
#  4    PI  220030          ALTO LONGÃ  2   13.479       1-AtÃ© 20mil hab.    2
#  ..   ..     ...                  ... ..      ...                     ...  ...
#  429  PR  411500             MARILENA  4    7.253       1-AtÃ© 20mil hab.    3
#  430  PR  411510              MARILUZ  3    9.847       1-AtÃ© 20mil hab.    3
#  431  PR  411520             MARINGÃ  5  409.657  4-Acima de 100mil hab.    4
#  432  PR  411530          MARIÃPOLIS  4    6.371       1-AtÃ© 20mil hab.    3
#  433  PR  411535              MARIPÃ  5    6.555       1-AtÃ© 20mil hab.    4
#
#  [434 rows x 7 columns],
#       PR  411540   MARMELEIRO  4  15.901                 1-AtÃ© 20mil hab.  3
#  0    PR  411545    MARQUINHO  3   4.515                 1-AtÃ© 20mil hab.  3
#  1    PR  411550      MARUMBI  4   4.699                 1-AtÃ© 20mil hab.  3
#  2    PR  411560  MATELÃNDIA  4  18.450                 1-AtÃ© 20mil hab.  3
#  3    PR  411570     MATINHOS  4  39.259  2-Acima de 20mil atÃ© 50mil hab.  4
#  4    PR  411573    MATO RICO  3   3.267                 1-AtÃ© 20mil hab.  3
#  ..   ..     ...          ... ..     ...                               ... ..
#  441  RN  241470      VÃRZEA  3   5.233                 1-AtÃ© 20mil hab.  3
#  442  RN  241475    VENHA-VER  1   3.014                 1-AtÃ© 20mil hab.  1
#  443  RN  241480    VERA CRUZ  3  10.735                 1-AtÃ© 20mil hab.  3
#  444  RN  241490      VIÃOSA  3   1.822                 1-AtÃ© 20mil hab.  3
#  445  RN  241500    VILA FLOR  2   3.174                 1-AtÃ© 20mil hab.  2
#
#  [446 rows x 7 columns],
#       RO  110001     ALTA FLORESTA D'OESTE  3  21.494  \
#  0    RO  110002                 ARIQUEMES  4  96.833
#  1    RO  110003                    CABIXI  4   5.351
#  2    RO  110004                    CACOAL  4  86.887
#  3    RO  110005                CEREJEIRAS  4  15.890
#  4    RO  110006         COLORADO DO OESTE  4  15.663
#  ..   ..     ...                       ... ..     ...
#  466  RS  431890         SÃO LUIZ GONZAGA  4  34.752
#  467  RS  431900               SÃO MARCOS  5  21.084
#  468  RS  431910             SÃO MARTINHO  4   5.481
#  469  RS  431912    SÃO MARTINHO DA SERRA  3   2.860
#  470  RS  431915  SÃO MIGUEL DAS MISSÃES  4   7.056
#
#        2-Acima de 20mil atÃ© 50mil hab.  3.1
#  0    3-Acima de 50mil atÃ© 100mil hab.    4
#  1                    1-AtÃ© 20mil hab.    3
#  2    3-Acima de 50mil atÃ© 100mil hab.    4
#  3                    1-AtÃ© 20mil hab.    3
#  4                    1-AtÃ© 20mil hab.    3
#  ..                                 ...  ...
#  466   2-Acima de 20mil atÃ© 50mil hab.    4
#  467   2-Acima de 20mil atÃ© 50mil hab.    4
#  468                  1-AtÃ© 20mil hab.    3
#  469                  1-AtÃ© 20mil hab.    3
#  470                  1-AtÃ© 20mil hab.    3
#
#  [471 rows x 7 columns],
#       RS  431920             SÃO NICOLAU  3   5.118  \
#  0    RS  431930  SÃO PAULO DAS MISSÃES  4   5.846
#  1    RS  431935      SÃO PEDRO DA SERRA  5   3.548
#  2    RS  431936  SÃO PEDRO DAS MISSÃES  4   1.757
#  3    RS  431937     SÃO PEDRO DO BUTIÃ  5   3.070
#  4    RS  431940        SÃO PEDRO DO SUL  4  15.577
#  ..   ..     ...                      ... ..     ...
#  456  SE  280720                   SIRIRI  2   7.834
#  457  SE  280730                    TELHA  3   3.274
#  458  SE  280740           TOBIAS BARRETO  2  50.905
#  459  SE  280750            TOMAR DO GERU  1  12.012
#  460  SE  280760                 UMBAÃBA  2  23.917
#
#                       1-AtÃ© 20mil hab.  3.1
#  0                    1-AtÃ© 20mil hab.    3
#  1                    1-AtÃ© 20mil hab.    4
#  2                    1-AtÃ© 20mil hab.    3
#  3                    1-AtÃ© 20mil hab.    4
#  4                    1-AtÃ© 20mil hab.    3
#  ..                                 ...  ...
#  456                  1-AtÃ© 20mil hab.    2
#  457                  1-AtÃ© 20mil hab.    3
#  458  3-Acima de 50mil atÃ© 100mil hab.    3
#  459                  1-AtÃ© 20mil hab.    1
#  460   2-Acima de 20mil atÃ© 50mil hab.    2
#
#  [461 rows x 7 columns],
#       SP  350010                ADAMANTINA  5  34.687  \
#  0    SP  350020                    ADOLFO  4   4.351
#  1    SP  350030                    AGUAÃ  4  32.072
#  2    SP  350040           ÃGUAS DA PRATA  5   7.369
#  3    SP  350050        ÃGUAS DE LINDÃIA  5  17.930
#  4    SP  350055  ÃGUAS DE SANTA BÃRBARA  5   7.177
#  ..   ..     ...                       ... ..     ...
#  395  SP  353520          PALMEIRA D'OESTE  4   8.903
#  396  SP  353530                  PALMITAL  5  19.594
#  397  SP  353540                  PANORAMA  4  14.964
#  398  SP  353550       PARAGUAÃU PAULISTA  4  41.120
#  399  SP  353560                 PARAIBUNA  4  17.667
#
#       2-Acima de 20mil atÃ© 50mil hab.  4
#  0                   1-AtÃ© 20mil hab.  3
#  1    2-Acima de 20mil atÃ© 50mil hab.  4
#  2                   1-AtÃ© 20mil hab.  4
#  3                   1-AtÃ© 20mil hab.  4
#  4                   1-AtÃ© 20mil hab.  4
#  ..                                ... ..
#  395                 1-AtÃ© 20mil hab.  3
#  396                 1-AtÃ© 20mil hab.  4
#  397                 1-AtÃ© 20mil hab.  3
#  398  2-Acima de 20mil atÃ© 50mil hab.  4
#  399                 1-AtÃ© 20mil hab.  3
#
#  [400 rows x 7 columns],
#          SP  353570           PARAÃSO                  4              6.099  \
#  0       SP  353580       PARANAPANEMA                  4             19.395
#  1       SP  353590         PARANAPUÃ                  5              4.031
#  2       SP  353600           PARAPUÃ                  4             10.580
#  3       SP  353610           PARDINHO                  5              7.153
#  4       SP  353620     PARIQUERA-AÃU                  4             19.233
#  ..     ...     ...                ...                ...                ...
#  378     TO  172125           TUPIRAMA                  4              1.909
#  379     TO  172130         TUPIRATINS                  2              1.874
#  380     TO  172208      WANDERLÃNDIA                  3             10.522
#  381     TO  172210           XAMBIOÃ                  2             10.517
#  382  Total   Total  5.570 municÃ­pios  5.570 municÃ­pios  5.570 municÃ­pios
#
#       1-AtÃ© 20mil hab.                  3
#  0    1-AtÃ© 20mil hab.                  3
#  1    1-AtÃ© 20mil hab.                  4
#  2    1-AtÃ© 20mil hab.                  3
#  3    1-AtÃ© 20mil hab.                  4
#  4    1-AtÃ© 20mil hab.                  3
#  ..                 ...                ...
#  378  1-AtÃ© 20mil hab.                  3
#  379  1-AtÃ© 20mil hab.                  2
#  380  1-AtÃ© 20mil hab.                  3
#  381  1-AtÃ© 20mil hab.                  2
#  382  5.570 municÃ­pios  5.570 municÃ­pios
#
#  [383 rows x 7 columns],
#  Empty DataFrame
#  Columns: [Visitantes Ãºnicos, null null null]
#  Index: []]

# %%
# Une todas as tabelas em uma só (concatenando as tabelas)
# indices_tabelas = pd.concat(indices, ignore_index=True)

# # Salva a tabela unificada em um arquivo CSV
# indices_tabelas.to_csv('tabelas_unificadas.csv', index=False)

# print("As tabelas foram unidas e salvas com sucesso em 'tabelas_unificadas.csv'.")

# %%
#url = 'https://www.in.gov.br/en/web/dou/-/portaria-gm/ms-n-3.493-de-10-de-abril-de-2024-553573811'

# %%
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36'}

# %%
#page = requests.get(url, headers=headers)

# %%
#type(page.text)

# %%
#soup = BeautifulSoup(page.text, 'html.parser')

# %%
#soup.find(By.CLASS_NAME, 'dou-table')

# %%
# # A classe Service é usada para iniciar uma instância do Chrome webDriver
# service = Service()

# # webdriver.ChromeOptions é usado para definir a preferência para o browser do Chromer
# options = webdriver.ChromeOptions()

# # Inicia-se a instância do Chrome webDriver com as definidas "options" e "service"
# driver = webdriver.Chrome(service=service, options=options)
